# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,axs = plt.subplots(2,3,figsize=(5,5))
ax00 = axs[0,0]
ax01 = axs[0,1]
#plt.axes(ax) don't do this
ax00.plot([0,1,2],[3,4,5],"b--",label="My Label",linewidth=7)
ax01.plot([3,4,5],[7,8,900])
#ax00.set_ylim([0,1000])
#ax01.set_ylim([0,1000])
ax00.set_yscale('log')
ax01.set_yscale('log')
#lines = ax.plot([0,1,2],[3,4,5])
#lines[0].set_linestyle("--")
#print(type(lines[0]))
ax00.set_xticks([0,2])
ax00.set_yticks([0,5])
ax00.set_xticklabels(["One","Two"])
ax00.set_title("Example")
ax00.set_xlabel("x-axis")
fig.suptitle("Example Suptitle")
fig.set_facecolor("white")
ax00.legend()
fig.tight_layout()
fig.savefig("results/tempfig.png")
